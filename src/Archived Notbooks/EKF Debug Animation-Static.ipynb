# %%
# %matplotlib inline
import numpy as np
from scipy import special
from matplotlib import pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML

import pickle as pkl
import networkx as nx

# %%
from matplotlib.lines import Line2D


expr= 'EKF-Debug'
filepath = "{}.pkl".format(expr)
with open(filepath,'rb') as file:
    record = pkl.load(file)


qs = record['src_locs']['source_1']

ps = np.array([locs for sensor, locs in record['sensor_locs'].items()])


fig, ax = plt.subplots(4,dpi=100)

fig.suptitle('Estimation vs Time.')
for _ in range(4):
    if _<2:
        ax[_].plot(qs[:30,_],'-.')
        custom_lines = [Line2D([0], [0], color='blue', ls='-.'),]
        ax[_].legend(custom_lines, ['True $q_{}$'.format(_)])
    for name,est in record['est_locs_log'].items():
        ax[_].plot(est[:30,_],label=name)
        ax[_].set_ylabel(r'$\hat z_{}$'.format(_))
#     ax[_].legend()

# %%
fig, ax = plt.subplots(dpi=100)
ax.cla()
G = record['comm_network'][0]
# nx.draw(G,pos=ps[:,0,:],ax=ax,label='Mobile Sensors',node_size=30) # ps.shape=(n_sensors,N_iter,space_dim)
ax.scatter(qs[0,0],qs[0,1],marker='*',s=50,label='Source')

for name,est in record['est_locs_log'].items():
    ax.scatter([est[:20,0]],[est[:20,1]],marker="*",s=50,label='Initial Guess')

ax.axis('on')
ax.axis('equal')
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)
# ax.set_xlim((-4,12))
# ax.set_ylim((-4,12))
ax.legend()
ax.set_title(expr+"\n t={}".format(0))
plt.show()

# %%
for name in record['Ks'].keys():
    plt.title(name)
#     for j in range(10):
#         print(record['Ks'][name][j])
    ave_K = np.array([np.max(np.abs(K),axis=1) for K in record['Ks'][name]])
    for i in range(ave_K.shape[1]):
        plt.plot(ave_K[:100,i],label=r'$K_{}$'.format(i))
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-159-8cd4b8842f8e> in <module>
#       4 #         print(record['Ks'][name][j])
#       5     ave_K = np.array([np.max(np.abs(K),axis=1) for K in record['Ks'][name]])
# ----> 6     for i in range(ave_K.shape[1]):
#       7         plt.plot(ave_K[:100,i],label=r'$K_{}$'.format(i))
#       8     plt.legend()
#
# IndexError: tuple index out of range

# %%
for name in record['ys'].keys():
    plt.title(name+" ys")
    plt.plot(record['ys'][name])
    plt.show()

# %%
for name in record['yhats'].keys():
    plt.title(name+" yhats")
    plt.plot(record['yhats'][name][:20])
    plt.show()

# %%
for name in record['Cs'].keys():
    plt.title(name)
    ave_C = np.array([np.max(np.abs(C),axis=0) for C in record['Cs'][name]])
    for i in range(ave_C.shape[1]):
        plt.plot(ave_C[:20,i],label=r'$C_{}$'.format(i))
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-164-a884d18abaca> in <module>
#       2     plt.title(name)
#       3     ave_C = np.array([np.max(np.abs(C),axis=0) for C in record['Cs'][name]])
# ----> 4     for i in range(ave_C.shape[1]):
#       5         plt.plot(ave_C[:20,i],label=r'$C_{}$'.format(i))
#       6     plt.legend()
#
# IndexError: tuple index out of range

# %%
for name in record['Ps'].keys():
    plt.title(name)
    eig_P = np.array([np.linalg.eigvals(P) for P in record['Ps'][name]])
    for i in range(eig_P.shape[1]):
        plt.plot(eig_P[:20,i],label=r'$\lambda_{}(P)$'.format(i))
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-165-a2c2a4c41f03> in <module>
#       2     plt.title(name)
#       3     eig_P = np.array([np.linalg.eigvals(P) for P in record['Ps'][name]])
# ----> 4     for i in range(eig_P.shape[1]):
#       5         plt.plot(eig_P[:20,i],label=r'$\lambda_{}(P)$'.format(i))
#       6     plt.legend()
#
# IndexError: tuple index out of range

# %%
for name in record['Ps'].keys():
    plt.title(name)
    Ps = record['Ps'][name]
    Cs = record['Cs'][name]
    cPc = [C.dot(P).dot(C.T) for P,C in zip(Ps,Cs)]
    eig_cPc = np.array([np.abs(np.linalg.eigvals(A)) for A in cPc ])
    for i in range(eig_cPc.shape[1]):
        plt.plot(eig_cPc[:20,i],label=r'$\lambda_{}(CPC^T)$'.format(i))
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-166-0628cbc58126> in <module>
#       5     cPc = [C.dot(P).dot(C.T) for P,C in zip(Ps,Cs)]
#       6     eig_cPc = np.array([np.abs(np.linalg.eigvals(A)) for A in cPc ])
# ----> 7     for i in range(eig_cPc.shape[1]):
#       8         plt.plot(eig_cPc[:20,i],label=r'$\lambda_{}(CPC^T)$'.format(i))
#       9     plt.legend()
#
# IndexError: tuple index out of range

# %%
for name in record['Ps'].keys():
    plt.title(name)
    Ps = record['Ps'][name]
    Cs = record['Cs'][name]
    cPPc = [C.dot(P).dot(P).dot(C.T) for P,C in zip(Ps,Cs)]
    eig_cPPc = np.array([np.abs(np.linalg.eigvals(cPPc)) for A in cPc ])
    for i in range(eig_cPc.shape[1]):
        plt.plot(eig_cPc[:20,i],label=r'$\lambda_{}(CPPC^T)$'.format(i))
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-167-ae1798810ba7> in <module>
#       5     cPPc = [C.dot(P).dot(P).dot(C.T) for P,C in zip(Ps,Cs)]
#       6     eig_cPPc = np.array([np.abs(np.linalg.eigvals(cPPc)) for A in cPc ])
# ----> 7     for i in range(eig_cPc.shape[1]):
#       8         plt.plot(eig_cPc[:20,i],label=r'$\lambda_{}(CPPC^T)$'.format(i))
#       9     plt.legend()
#
# IndexError: tuple index out of range

# %% [markdown]
# ## Animate experiment

# %%
expr= "EKF-Debug"
filepath = "{}.pkl".format(expr)
with open(filepath,'rb') as file:
    record = pkl.load(file)
    
ps = np.array([locs for sensor, locs in record['sensor_locs'].items()])
qs = record['src_locs']['source_1']
N_iter = ps.shape[1]

fig, ax = plt.subplots(dpi=100)
def plot_single_frame(j):
    ax.cla()
    G = record['comm_network'][0]
    nx.draw(G,pos=ps[:,j,:],ax=ax,label='Mobile Sensors',node_size=30) # ps.shape=(n_sensors,N_iter,space_dim)
    ax.scatter(qs[j,0],qs[j,1],marker='*',s=50,label='Source')
    ax.axis('on')
    ax.axis('equal')
    ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)
    ax.set_xlim((-4,12))
    ax.set_ylim((-4,12))
    ax.legend()
    ax.set_title(expr+"\n t={}".format(j))
    plt.show()


# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, plot_single_frame,
                               frames=N_iter,interval=100)
anim.save('{}.mp4'.format(expr))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      75         try:
# ---> 76             reduction = getattr(obj, method)
#      77         except AttributeError:
#
# AttributeError: 'bool' object has no attribute 'any'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     229         try:
# --> 230             yield self
#     231         finally:
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1151                         # TODO: See if turning off blit is really necessary
# -> 1152                         anim._draw_next_frame(d, blit=False)
#    1153                         if progress_callback is not None:
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1191         self._pre_draw(framedata, blit)
# -> 1192         self._draw_frame(framedata)
#    1193         self._post_draw(framedata, blit)
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1754         # func needs to return a sequence of any artists that were modified.
# -> 1755         self._drawn_artists = self._func(framedata, *self._args)
#    1756         if self._blit:
#
# <ipython-input-11-f338d1a1ac97> in plot_single_frame(j)
#      11 def plot_single_frame(j):
# ---> 12     ax.cla()
#      13     G = record['comm_network'][0]
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/axes/_base.py in cla(self)
#     973         self.xaxis.cla()
# --> 974         self.yaxis.cla()
#     975
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/axis.py in cla(self)
#     834
# --> 835         self.reset_ticks()
#     836
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/axis.py in reset_ticks(self)
#     857         try:
# --> 858             self.set_clip_path(self.axes.patch)
#     859         except AttributeError:
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     946         martist.Artist.set_clip_path(self, clippath, transform)
# --> 947         for child in self.majorTicks + self.minorTicks:
#     948             child.set_clip_path(clippath, transform)
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     673                 instance.minorTicks = []
# --> 674                 tick = instance._get_tick(major=False)
#     675                 instance.minorTicks.append(tick)
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2222             tick_kw = self._minor_tick_kw
# -> 2223         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2224
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     157
# --> 158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     576
# --> 577         l = mlines.Line2D((0,), (0,),
#     578                           color=self._color,
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     396
# --> 397         self.set_markerfacecolor(markerfacecolor)
#     398         self.set_markerfacecoloralt(markerfacecoloralt)
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/lines.py in set_markerfacecolor(self, fc)
#    1252             fc = 'auto'
# -> 1253         if np.any(self._markerfacecolor != fc):
#    1254             self.stale = True
#
# <__array_function__ internals> in any(*args, **kwargs)
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/numpy/core/fromnumeric.py in any(a, axis, out, keepdims)
#    2329     """
# -> 2330     return _wrapreduction(a, np.logical_or, 'any', axis, None, out, keepdims=keepdims)
#    2331
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      75         try:
# ---> 76             reduction = getattr(obj, method)
#      77         except AttributeError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-11-f338d1a1ac97> in <module>
#      27 anim = animation.FuncAnimation(fig, plot_single_frame,
#      28                                frames=N_iter,interval=100)
# ---> 29 anim.save('{}.mp4'.format(expr))
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                             progress_callback(frame_number, total_frames)
#    1155                             frame_number += 1
# -> 1156                     writer.grab_frame(**savefig_kwargs)
#    1157
#    1158         # Reconnect signal for first draw if necessary
#
# ~/miniconda3/envs/basics/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/animation.py in finish(self)
#     365     def finish(self):
#     366         '''Finish any processing for writing the movie.'''
# --> 367         self.cleanup()
#     368
#     369     def grab_frame(self, **savefig_kwargs):
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/matplotlib/animation.py in cleanup(self)
#     408                 "MovieWriter stderr:\n%s", err)
#     409         if self._proc.returncode:
# --> 410             raise subprocess.CalledProcessError(
#     411                 self._proc.returncode, self._proc.args, out, err)
#     412
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '600x400', '-pix_fmt', 'rgba', '-r', '10.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', 'EKF-Debug.mp4']' returned non-zero exit status 255.

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="600" height="400" controls autoplay loop>
#   <source type="video/mp4" src="...
