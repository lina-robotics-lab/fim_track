# %%
import numpy as np
from matplotlib import pyplot as plt

import pickle as pkl
from matplotlib import style
import jax.numpy as jnp
from jax import jacfwd, jit,grad
from functools import partial


from Robot import Robot
from virtual_sensor import virtual_sensor
from utils.DynamicFilters import getDynamicFilter
from utils.FIMPathPlanning import FIM_ascent_path_planning 
from utils.dLdp import analytic_dLdp
from utils.regions import CircleExterior
from tracking_log import logger

style.use('fivethirtyeight')

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Plotting Utilities

# %%
def plot_trajectory(ax,traj,name,marker,size=50):
    def direction_at(i):
        direction = traj[i+1,:]-traj[i,:]
        return traj[i,0],traj[i,1], direction[0],direction[1]
    
    ax.scatter(traj[:,0],traj[:,1],label=name,marker=marker,s = size)
	


    
def plot_dist_to_source(ax,log):
    src_locs = log['src_locs']['source_1']
    for key,sensor_locs in log['sensor_locs'].items():
        l = np.min([len(sensor_locs),len(src_locs)])
        dist = np.linalg.norm(sensor_locs[:l]-src_locs[:l],axis = 1)
        ax.plot(dist,label = key)
    ax.set_title('Sensor-Source Distance vs Time steps',fontsize=15)
    ax.set_xlabel('Time Steps')
#     ax.legend()
    
def plot_L(ax,log):
    q = log['src_locs']['source_1']
    ps = []
    for key,sensor_locs in log['sensor_locs'].items():
        l = np.min([len(sensor_locs),len(q)])
        ps.append(sensor_locs[:l])
    ps = np.hstack(ps).reshape(-1,3,2)
    Ls = [f_L(q[i,:],ps[i,:]) for i in range(l)]
    ax.plot(np.log(Ls),label = r'$\log(L(p,q))$')
    
    for key,qhat in log['est_locs_log'].items():
        if key in["ekf"]:            
            Lhat = [f_L(qhat[i,:],ps[i,:]) for i in range(l)]
            ax.plot(np.log(Lhat),label = r'$\log(L(p,qhat))$')
      
    ax.legend(loc='lower right')
#     ax.set_title('log(L(ps,q)) vs Time steps',fontsize=15)
    ax.set_ylabel('log loss')

def plot_all(log,main_title,save_file_name):
    fig = plt.figure(dpi=100,figsize=(10,10))
    gs = fig.add_gridspec(2,1)

    
    ax = fig.add_subplot(gs[0,:])
    rectangle = plt.Rectangle((0,0), 3, 3, alpha=0.3,fc='red',ec="red")
    ax.add_artist(rectangle)
    ax.text(0.5,1.5,'Starting Region of the Sensors')
    plot_experiment(ax,log)
    
    ax = fig.add_subplot(gs[1,:])
    plot_dist_to_source(ax,log)
    
    
    ax.set_title(main_title,fontsize=20)
    
    fig.tight_layout()

    plt.savefig(save_file_name,bbox_inches='tight')


# animation function. This is called sequentially
def plot_experiment(ax,log):
#     ax.clear()

#     ax.set_xlim((0,7))
#     ax.set_ylim((0,7))

    ax.set_aspect('equal',adjustable='box')
           
    
    for key,val in log['src_locs'].items():
        plot_trajectory(ax,val,'Static Source','*',size = 400)

    for key,val in log['sensor_locs'].items():
        plot_trajectory(ax,val,"",'.',size=200)
    

    ax.legend(loc='right')
    ax.set_xlabel('x')
    ax.set_ylabel('y')

# %%
def random_initial_poses(n_sensors,xmin,xmax,ymin,ymax):
    sensor_poses = np.zeros((n_sensors,2))
    sensor_poses[:,0]= xmin + np.random.rand(n_sensors)*(xmax-xmin)
    sensor_poses[:,1]= ymin + np.random.rand(n_sensors)*(ymax-ymin)
    return sensor_poses

# %% [markdown]
# ## Main Loop

# %%
def main(n_sensors,std, N,fplan):
    
    # Set up mobile sensors and sources
    src_locs = [[6.,6]]
    src_names = ["source_{}".format(i+1) for i in range(len(src_locs))]
    source = [Robot(loc,name) for loc,name in zip(src_locs,src_names)]

    initial_locs = random_initial_poses(n_sensors,xmin=0,xmax=3,ymin=0,ymax=3)
    sensor_names = ["mobile_sensor_{}".format(i+1) for i in range(len(initial_locs))]
    mobile_sensors = [Robot(loc,name) for loc,name in zip(initial_locs,sensor_names)]

    CoM = np.mean(initial_locs,axis=0)

    ## Set up virtual sensors
    C1=0
    C0=0
    k=1
    b=-2
    vs = virtual_sensor(C1,C0,b,k,std)
    
    # Set up location estimator
#     n_sensors = len(mobile_sensors)
    n_src = len(source)

    C1s=C1*np.ones(n_sensors)
    C0s = C0*np.ones(n_sensors)
    ks = k * np.ones(n_sensors)
    bs = b*np.ones(n_sensors)
    initial_guess = np.array([4.,2.])
    xlim = (-np.inf,np.inf)
    ylim = (-np.inf,np.inf)

    estimator = getDynamicFilter(len(mobile_sensors),len(source),C1s,C0s,ks,bs,initial_guess,filterType="ekf",xlim=xlim,ylim=ylim)
    estimator_name = 'ekf'
    



    # Set up data logger
    log = logger(sensor_names,src_names)

    # Main Loop
   

    for _ in range(N):


        # Record
        for s in source:
            log.src_locs[s.name].append(s.loc)

        for m in mobile_sensors:
            log.sensor_locs[m.name].append(m.loc)

        # Measure
        ps = np.array([r.loc for r in mobile_sensors])
        qs = np.array([s.loc for s in source])
        y = vs.measurement(qs,ps)
        
       # Estimate
        qhat = estimator.update_and_estimate_loc(ps,y)
        
        # Plan
        waypoints = fplan(qhat,ps)
        # Move
        for i in range(n_sensors):
            mobile_sensors[i].update_loc(waypoints[0][i])

    return log

# %%
# Set up waypoint planner
n_sensors=3
C0=0
C1 = -0.5
k=1
b=-2
C1s=C1*np.ones(n_sensors)
C0s = C0*np.ones(n_sensors)
ks = k * np.ones(n_sensors)
bs = b*np.ones(n_sensors)

f_dLdp=dLdp(C1s=C1s,C0s=C0s,ks=ks,bs=bs)
planning_timesteps = 1
max_linear_speed = 0.22
planning_dt = 1
epsilon = 0.1
# The FIM waypoint planning  
fplan = lambda qs,ps:FIM_ascent_path_planning(f_dLdp,qs,ps,n_sensors,\
                planning_timesteps,\
                max_linear_speed,\
                planning_dt,\
                epsilon,\
                # Rect2D(self.xlim,self.ylim))
                CircleExterior(np.array([6,6]),0))

log = main(n_sensors,0.01,100,fplan)
plot_all(log.export(),'test','test.png')

# %% [markdown]
# ## Run experiments and save data

# %%
def get_dists_to_src(log):
    src_locs = log['src_locs']['source_1']
    dists = []
    for key,sensor_locs in log['sensor_locs'].items():
        l = np.min([len(sensor_locs),len(src_locs)])
        dists.append(np.linalg.norm(sensor_locs[:l]-src_locs[:l],axis = 1))
    return np.array(dists)

# %%
# Experiment parameters
noise_std = 0.01
N_steps = 100
N_expr = 100
N_sensors = [3,10,20,50]

# %%
# Data container
experiment = {n:[] for n in N_sensors}

for n_sensors in N_sensors:
    print(n_sensors)
    dists = []
    
    # Set up fplan
    C1=0
    C0=-0.5
    k=1
    b=-2
    C1s=C1*np.ones(n_sensors)
    C0s = C0*np.ones(n_sensors)
    ks = k * np.ones(n_sensors)
    bs = b*np.ones(n_sensors)

    f_dLdp=partial(analytic_dLdp,C1s=C1s,C0s=C0s,ks=ks,bs=bs)
    planning_timesteps = 1
    max_linear_speed = 0.22
    planning_dt = 1
    epsilon = 0.1
    # The FIM waypoint planning  
    fplan = lambda qs,ps:FIM_ascent_path_planning(f_dLdp,qs,ps,n_sensors,\
                    planning_timesteps,\
                    max_linear_speed,\
                    planning_dt,\
                    epsilon,\
                    # Rect2D(self.xlim,self.ylim))
                    CircleExterior(np.array([6,6]),0))
    
    for _ in range(N_expr):
        print("{} in {} experiments finished".format(_,N_expr))
        log=main(n_sensors,noise_std,N_steps,fplan)
        dists.append(get_dists_to_src(log.export()))
    data = {'format':'dists[num_experiments,n_sensor,N_steps]','data':np.array(dists)}
    experiment[n_sensors]=data
# Out:
# 3
# 0 in 100 experiments finished
# 1 in 100 experiments finished
# 2 in 100 experiments finished
# 3 in 100 experiments finished
# 4 in 100 experiments finished
# 5 in 100 experiments finished
# 6 in 100 experiments finished
# 7 in 100 experiments finished
# 8 in 100 experiments finished
# 9 in 100 experiments finished
# 10 in 100 experiments finished
# 11 in 100 experiments finished
# 12 in 100 experiments finished
# 13 in 100 experiments finished
# 14 in 100 experiments finished
# 15 in 100 experiments finished
# 16 in 100 experiments finished
# 17 in 100 experiments finished
# 18 in 100 experiments finished
# 19 in 100 experiments finished
# 20 in 100 experiments finished
# 21 in 100 experiments finished
# 22 in 100 experiments finished
# 23 in 100 experiments finished
# 24 in 100 experiments finished
# 25 in 100 experiments finished
# 26 in 100 experiments finished
# 27 in 100 experiments finished
# 28 in 100 experiments finished
# 29 in 100 experiments finished
# 30 in 100 experiments finished
# 31 in 100 experiments finished
# 32 in 100 experiments finished
# 33 in 100 experiments finished
# 34 in 100 experiments finished
# 35 in 100 experiments finished
# 36 in 100 experiments finished
# 37 in 100 experiments finished
# 38 in 100 experiments finished
# 39 in 100 experiments finished
# 40 in 100 experiments finished
# 41 in 100 experiments finished
# 42 in 100 experiments finished
# 43 in 100 experiments finished
# 44 in 100 experiments finished
# 45 in 100 experiments finished
# 46 in 100 experiments finished
# 47 in 100 experiments finished
# 48 in 100 experiments finished
# 49 in 100 experiments finished
# 50 in 100 experiments finished
# 51 in 100 experiments finished
# 52 in 100 experiments finished
# 53 in 100 experiments finished
# 54 in 100 experiments finished
# 55 in 100 experiments finished
# 56 in 100 experiments finished
# 57 in 100 experiments finished
# 58 in 100 experiments finished
# 59 in 100 experiments finished
# 60 in 100 experiments finished
# 61 in 100 experiments finished
# 62 in 100 experiments finished
# 63 in 100 experiments finished
# 64 in 100 experiments finished
# 65 in 100 experiments finished
# 66 in 100 experiments finished
# 67 in 100 experiments finished
# 68 in 100 experiments finished
# 69 in 100 experiments finished
# 70 in 100 experiments finished
# 71 in 100 experiments finished
# 72 in 100 experiments finished
# 73 in 100 experiments finished
# 74 in 100 experiments finished
# 75 in 100 experiments finished
# 76 in 100 experiments finished
# 77 in 100 experiments finished
# 78 in 100 experiments finished
# 79 in 100 experiments finished
# 80 in 100 experiments finished
# 81 in 100 experiments finished
# 82 in 100 experiments finished
# 83 in 100 experiments finished
# 84 in 100 experiments finished
# 85 in 100 experiments finished
# 86 in 100 experiments finished
# 87 in 100 experiments finished
# 88 in 100 experiments finished
# 89 in 100 experiments finished
# 90 in 100 experiments finished
# 91 in 100 experiments finished
# 92 in 100 experiments finished
# 93 in 100 experiments finished
# 94 in 100 experiments finished
# 95 in 100 experiments finished
# 96 in 100 experiments finished
# 97 in 100 experiments finished
# 98 in 100 experiments finished
# 99 in 100 experiments finished
# 10
# 0 in 100 experiments finished
# 1 in 100 experiments finished
# 2 in 100 experiments finished
# 3 in 100 experiments finished
# 4 in 100 experiments finished
# 5 in 100 experiments finished
# 6 in 100 experiments finished
# 7 in 100 experiments finished
# 8 in 100 experiments finished
# 9 in 100 experiments finished
# 10 in 100 experiments finished
# 11 in 100 experiments finished
# 12 in 100 experiments finished
# 13 in 100 experiments finished
# 14 in 100 experiments finished
# 15 in 100 experiments finished
# 16 in 100 experiments finished
# 17 in 100 experiments finished
# 18 in 100 experiments finished
# 19 in 100 experiments finished
# 20 in 100 experiments finished
# 21 in 100 experiments finished
# 22 in 100 experiments finished
# 23 in 100 experiments finished
# 24 in 100 experiments finished
# 25 in 100 experiments finished
# 26 in 100 experiments finished
# 27 in 100 experiments finished
# 28 in 100 experiments finished
# 29 in 100 experiments finished
# 30 in 100 experiments finished
# 31 in 100 experiments finished
# 32 in 100 experiments finished
# 33 in 100 experiments finished
# 34 in 100 experiments finished
# 35 in 100 experiments finished
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-a5a4b1d5d646> in <module>
#      32     for _ in range(N_expr):
#      33         print("{} in {} experiments finished".format(_,N_expr))
# ---> 34         log=main(n_sensors,noise_std,N_steps,fplan)
#      35         dists.append(get_dists_to_src(log.export()))
#      36     data = {'format':'dists[num_experiments,n_sensor,N_steps]','data':np.array(dists)}
#
# <ipython-input-10-e8b971945090> in main(n_sensors, std, N, fplan)
#      59
#      60        # Estimate
# ---> 61         qhat = estimator.update_and_estimate_loc(ps,y)
#      62
#      63         # Plan
#
# ~/Desktop/fim_track/src/utils/DynamicFilters.py in update_and_estimate_loc(self, ps, meas)
#     127
#     128                 if not np.any(meas == np.inf):
# --> 129                         self.update_filters(ps,meas)
#     130
#     131                 return self.current_state_corrected()[:2]
#
# ~/Desktop/fim_track/src/utils/DynamicFilters.py in update_filters(self, new_ps, new_measurements)
#     144                         region = Rect2D(self.xlim,self.ylim)
#     145                         if self.filterType=='ekf':
# --> 146                                 self.filter.update(new_measurements,self.dhxdx,self.hx)
#     147                                 # Perform projection onto the region of motion.
#     148                                 self.filter.x_post[:2] = region.project_point(self.filter.x_post[:2])
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/filterpy/kalman/EKF.py in update(self, z, HJacobian, Hx, R, args, hx_args, residual)
#     321         self.K = PHT.dot(linalg.inv(self.S))
#     322
# --> 323         hx = Hx(self.x, *hx_args)
#     324         self.y = residual(z, hx)
#     325         self.x = self.x + dot(self.K, self.y)
#
# ~/Desktop/fim_track/src/utils/DynamicFilters.py in hx(self, x)
#     166
#     167         def hx(self,x):
# --> 168                 return self.meas_func(x,self.ps)
#     169
#     170         # Use jax to automatically compute the jacobian of measurement function, with respect to state only.
#
# ~/Desktop/fim_track/src/utils/DynamicFilters.py in joint_meas_func(C1s, C0s, ks, bs, x, ps)
#      41
#      42         # Keep in mind that x is a vector of [q,q'], thus only the first half of components are observable.
# ---> 43         dists=jnp.linalg.norm(x[:len(x)//2]-p,axis=1)
#      44
#      45         return single_meas_func(C1,C0,k,b,dists)
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/numpy/lax_numpy.py in deferring_binary_op(self, other)
#    4136     if not isinstance(other, _scalar_types + _arraylike_types + (core.Tracer,)):
#    4137       return NotImplemented
# -> 4138     return binary_op(self, other)
#    4139   return deferring_binary_op
#    4140
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/numpy/lax_numpy.py in <lambda>(x, y)
#    4140
#    4141 def _swap_args(f):
# -> 4142   return lambda x, y: f(y, x)
#    4143
#    4144 def _unimplemented_setitem(self, i, x):
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/numpy/lax_numpy.py in <lambda>(x1, x2)
#     330     fn = lambda x1, x2: lax_fn(*_promote_args_inexact(numpy_fn, x1, x2))
#     331   else:
# --> 332     fn = lambda x1, x2: lax_fn(*_promote_args(numpy_fn.__name__, x1, x2))
#     333   return _wraps(numpy_fn)(fn)
#     334
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/lax/lax.py in sub(x, y)
#     297 def sub(x: Array, y: Array) -> Array:
#     298   r"""Elementwise subtraction: :math:`x - y`."""
# --> 299   return sub_p.bind(x, y)
#     300
#     301 def mul(x: Array, y: Array) -> Array:
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/core.py in bind(self, *args, **kwargs)
#     257     top_trace = find_top_trace(args)
#     258     if top_trace is None:
# --> 259       return self.impl(*args, **kwargs)
#     260
#     261     tracers = map(top_trace.full_raise, args)
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/interpreters/xla.py in apply_primitive(prim, *args, **params)
#     224   """Impl rule that compiles and runs a single primitive 'prim' using XLA."""
#     225   compiled_fun = xla_primitive_callable(prim, *map(arg_spec, args), **params)
# --> 226   return compiled_fun(*args)
#     227
#     228 @cache()
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/interpreters/xla.py in _execute_compiled_primitive(prim, compiled, result_handler, *args)
#     322 def _execute_compiled_primitive(prim, compiled, result_handler, *args):
#     323   device, = compiled.local_devices()
# --> 324   input_bufs = [device_put(x, device) for x in args if x is not token]
#     325   out_bufs = compiled.execute(input_bufs)
#     326   if FLAGS.jax_debug_nans:
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/interpreters/xla.py in <listcomp>(.0)
#     322 def _execute_compiled_primitive(prim, compiled, result_handler, *args):
#     323   device, = compiled.local_devices()
# --> 324   input_bufs = [device_put(x, device) for x in args if x is not token]
#     325   out_bufs = compiled.execute(input_bufs)
#     326   if FLAGS.jax_debug_nans:
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/interpreters/xla.py in device_put(x, device)
#     112   x = canonicalize_dtype(x)
#     113   try:
# --> 114     return device_put_handlers[type(x)](x, device)
#     115   except KeyError as err:
#     116     raise TypeError(f"No device_put handler for type: {type(x)}") from err
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/interpreters/xla.py in _device_put_device_array(x, device)
#    1111
#    1112 def _device_put_device_array(x: DeviceArray, device: Optional[Device]):
# -> 1113   x = _copy_device_array_to_device(x, device)
#    1114   return _force(x).device_buffer
#    1115 device_put_handlers[DeviceArray] = _device_put_device_array
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/interpreters/xla.py in _copy_device_array_to_device(x, device)
#    1119     # no copying to be done because there's no target specified
#    1120     return x
# -> 1121   elif is_device_constant(x):
#    1122     # create a new DeviceArray with the same lazy expr, no copying
#    1123     return DeviceArray(x.aval, device, x._lazy_expr, DeviceConstant(device))
#
# ~/miniconda3/envs/basics/lib/python3.8/site-packages/jax/interpreters/xla.py in is_device_constant(x)
#    1094   def to_py(self): return None
#    1095
# -> 1096 def is_device_constant(x):
#    1097   return type(x) is DeviceArray and type(x.device_buffer) is DeviceConstant
#    1098
#
# KeyboardInterrupt:

# %%
filename = 'FIMDists.pkl'
pkl.dump(experiment,open(filename,'wb'))

# %%
filename = 'FIMDists.pkl'
experiment = pkl.load(open(filename,'rb'))

# %%
metrics = {'median':np.median,'average':np.mean,'max':np.max,'min':np.min}
for metric_name,metric_method in metrics.items():
    plt.figure(figsize=(10,5))
    for n_sensor in N_sensors:
        metric = metric_method(experiment[n_sensor]['data'],axis=1)
        dist = np.mean(metric,axis=0)
        sd = np.std(metric,axis = 0)
        x=range(len(dist))
        plt.plot(x,dist)
        plt.fill_between(x,dist-sd,dist+sd,alpha=0.2,label = '{} sensors'.format(n_sensor))
    plt.xlabel('Time steps')
    plt.ylabel('src-sensor distance')
    plt.title("Algorithm: Location Estimation+Optimizing FIM.\n Metric: {} of src-sensor distances across sensors".format(metric_name))
    plt.legend()
    plt.tight_layout()
    plt.savefig("FIM{}.png".format(metric_name))
    plt.show()
